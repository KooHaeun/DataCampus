# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/Shareddrives/데이터 청년 캠퍼스/젓가락질 데이터/새 젓가락질 데이터/excel 파일/newdata1_notcorrect.xlsx'

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import io
import imageio
from IPython.display import Image, display
from ipywidgets import widgets, Layout, HBox

# %%
data = pd.read_excel(path)

# %%
data.head()
# Out:
#    Unnamed: 0       x_0       y_0  ...      z_16  y                            image
# 0           0  0.842716  0.782446  ...  0.096160  0  not_correct6.mp4_000000.865.jpg
# 1           1  0.833609  0.812045  ...  0.104297  0  not_correct6.mp4_000001.133.jpg
# 2           2  0.827795  0.811853  ...  0.097003  0  not_correct6.mp4_000001.067.jpg
# 3           3  0.822658  0.805489  ...  0.060277  0  not_correct6.mp4_000000.995.jpg
# 4           4  0.822961  0.789329  ...  0.047452  0  not_correct6.mp4_000000.931.jpg
#
# [5 rows x 54 columns]

# %%
scaler = MinMaxScaler()
data[['x_0','y_0','z_0','x_1','y_1','z_1','x_2','y_2','z_2','x_3','y_3','z_3','x_4','y_4','z_4','x_5','y_5','z_5','x_6','y_6','z_6','x_7','y_7','z_7','x_8','y_8','z_8','x_9','y_9','z_9','x_10','y_10','z_10','x_11','y_11','z_11','x_12','y_12','z_12','x_13','y_13','z_13','x_14','y_14','z_14','x_15','y_15','z_15','x_16','y_16','z_16']] = scaler.fit_transform(data[['x_0','y_0','z_0','x_1','y_1','z_1','x_2','y_2','z_2','x_3','y_3','z_3','x_4','y_4','z_4','x_5','y_5','z_5','x_6','y_6','z_6','x_7','y_7','z_7','x_8','y_8','z_8','x_9','y_9','z_9','x_10','y_10','z_10','x_11','y_11','z_11','x_12','y_12','z_12','x_13','y_13','z_13','x_14','y_14','z_14','x_15','y_15','z_15','x_16','y_16','z_16']])
data.head()
# Out:
#    Unnamed: 0       x_0       y_0  ...      z_16  y                            image
# 0           0  0.826732  0.370366  ...  0.754935  0  not_correct6.mp4_000000.865.jpg
# 1           1  0.656983  0.892241  ...  0.795168  0  not_correct6.mp4_000001.133.jpg
# 2           2  0.548596  0.888854  ...  0.759104  0  not_correct6.mp4_000001.067.jpg
# 3           3  0.452838  0.776649  ...  0.577514  0  not_correct6.mp4_000000.995.jpg
# 4           4  0.458500  0.491726  ...  0.514103  0  not_correct6.mp4_000000.931.jpg
#
# [5 rows x 54 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  97 non-null     int64
#  1   x_0         97 non-null     float64
#  2   y_0         97 non-null     float64
#  3   z_0         97 non-null     float64
#  4   x_1         97 non-null     float64
#  5   y_1         97 non-null     float64
#  6   z_1         97 non-null     float64
#  7   x_2         97 non-null     float64
#  8   y_2         97 non-null     float64
#  9   z_2         97 non-null     float64
#  10  x_3         97 non-null     float64
#  11  y_3         97 non-null     float64
#  12  z_3         97 non-null     float64
#  13  x_4         97 non-null     float64
#  14  y_4         97 non-null     float64
#  15  z_4         97 non-null     float64
#  16  x_5         97 non-null     float64
#  17  y_5         97 non-null     float64
#  18  z_5         97 non-null     float64
#  19  x_6         97 non-null     float64
#  20  y_6         97 non-null     float64
#  21  z_6         97 non-null     float64
#  22  x_7         97 non-null     float64
#  23  y_7         97 non-null     float64
#  24  z_7         97 non-null     float64
#  25  x_8         97 non-null     float64
#  26  y_8         97 non-null     float64
#  27  z_8         97 non-null     float64
#  28  x_9         97 non-null     float64
#  29  y_9         97 non-null     float64
#  30  z_9         97 non-null     float64
#  31  x_10        97 non-null     float64
#  32  y_10        97 non-null     float64
#  33  z_10        97 non-null     float64
#  34  x_11        97 non-null     float64
#  35  y_11        97 non-null     float64
#  36  z_11        97 non-null     float64
#  37  x_12        97 non-null     float64
#  38  y_12        97 non-null     float64
#  39  z_12        97 non-null     float64
#  40  x_13        97 non-null     float64
#  41  y_13        97 non-null     float64
#  42  z_13        97 non-null     float64
#  43  x_14        97 non-null     float64
#  44  y_14        97 non-null     float64
#  45  z_14        97 non-null     float64
#  46  x_15        97 non-null     float64
#  47  y_15        97 non-null     float64
#  48  z_15        97 non-null     float64
#  49  x_16        97 non-null     float64
#  50  y_16        97 non-null     float64
#  51  z_16        97 non-null     float64
#  52  y           97 non-null     int64
#  53  image       97 non-null     object
# dtypes: float64(51), int64(2), object(1)
# memory usage: 41.0+ KB

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f'{device} is available')
# Out:
# cpu is available

# %%
X = data[['x_0','y_0','z_0','x_1','y_1','z_1','x_2','y_2','z_2','x_3','y_3','z_3','x_4','y_4','z_4','x_5','y_5','z_5','x_6','y_6','z_6','x_7','y_7','z_7','x_8','y_8','z_8','x_9','y_9','z_9','x_10','y_10','z_10','x_11','y_11','z_11','x_12','y_12','z_12','x_13','y_13','z_13','x_14','y_14','z_14','x_15','y_15','z_15','x_16','y_16','z_16']].values
y = data['image'].values

# %%
def seq_data(x, y, sequence_length):

  x_seq = []
  y_seq = []
  for i in range(len(x) - sequence_length):
    x_seq.append(x[i: i+sequence_length])
    y_seq.append(y[i+sequence_length])

  return torch.FloatTensor(x_seq).to(device), torch.FloatTensor(y_seq).to(device).view([-1, 1])

# %%
split = 200
sequence_length = 50

x_seq, y_seq = seq_data(X, y, sequence_length)

x_train_seq = x_seq[:split]
y_train_seq = y_seq[:split]
x_test_seq = x_seq[split:]
y_test_seq = y_seq[split:]
print(x_train_seq.size(), y_train_seq.size())
print(x_test_seq.size(), y_test_seq.size())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-26640de1dbf5> in <module>()
#       2 sequence_length = 50
#       3
# ----> 4 x_seq, y_seq = seq_data(X, y, sequence_length)
#       5
#       6 x_train_seq = x_seq[:split]
#
# <ipython-input-48-27c0bbb01a86> in seq_data(x, y, sequence_length)
#       7     y_seq.append(y[i+sequence_length])
#       8
# ----> 9   return torch.FloatTensor(x_seq).to(device), torch.FloatTensor(y_seq).to(device).view([-1, 1])
#
# ValueError: too many dimensions 'str'
