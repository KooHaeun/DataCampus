# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path1='/content/drive/Shareddrives/데이터 청년 캠퍼스/젓가락질 데이터/새 젓가락질 데이터/excel 파일/newdata_all_0818.xlsx'

# %%
# from google.colab import files

# upload = files.upload()

# %%
import numpy as np
import pandas as pd

import copy

from numpy import *
from pandas import *

# %%
df = pd.read_excel(path1)

# %%
df
# Out:
#            x_0       y_0  ...  y                             image
# 0     0.813085  0.846067  ...  0  not_correct10.MP4_000002.243.jpg
# 1     0.811608  0.900154  ...  0  not_correct10.MP4_000004.040.jpg
# 2     0.804972  0.898247  ...  0  not_correct10.MP4_000004.240.jpg
# 3     0.810611  0.890062  ...  0  not_correct10.MP4_000004.440.jpg
# 4     0.813915  0.895303  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183  0.845585  0.939924  ...  1       correct4.mp4_000005.383.jpg
# 1184  0.846682  0.942074  ...  1       correct4.mp4_000005.450.jpg
# 1185  0.843230  0.931821  ...  1       correct4.mp4_000005.517.jpg
# 1186  0.846199  0.936584  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.844087  0.922825  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 53 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            x_0       y_0  ...  y                             image
# 0     0.813085  0.846067  ...  0  not_correct10.MP4_000002.243.jpg
# 1     0.811608  0.900154  ...  0  not_correct10.MP4_000004.040.jpg
# 2     0.804972  0.898247  ...  0  not_correct10.MP4_000004.240.jpg
# 3     0.810611  0.890062  ...  0  not_correct10.MP4_000004.440.jpg
# 4     0.813915  0.895303  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183  0.845585  0.939924  ...  1       correct4.mp4_000005.383.jpg
# 1184  0.846682  0.942074  ...  1       correct4.mp4_000005.450.jpg
# 1185  0.843230  0.931821  ...  1       correct4.mp4_000005.517.jpg
# 1186  0.846199  0.936584  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.844087  0.922825  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 53 columns]>

# %%
df.dtypes
# Out:
# x_0      float64
# y_0      float64
# z_0      float64
# x_1      float64
# y_1      float64
# z_1      float64
# x_2      float64
# y_2      float64
# z_2      float64
# x_3      float64
# y_3      float64
# z_3      float64
# x_4      float64
# y_4      float64
# z_4      float64
# x_5      float64
# y_5      float64
# z_5      float64
# x_6      float64
# y_6      float64
# z_6      float64
# x_7      float64
# y_7      float64
# z_7      float64
# x_8      float64
# y_8      float64
# z_8      float64
# x_9      float64
# y_9      float64
# z_9      float64
# x_10     float64
# y_10     float64
# z_10     float64
# x_11     float64
# y_11     float64
# z_11     float64
# x_12     float64
# y_12     float64
# z_12     float64
# x_13     float64
# y_13     float64
# z_13     float64
# x_14     float64
# y_14     float64
# z_14     float64
# x_15     float64
# y_15     float64
# z_15     float64
# x_16     float64
# y_16     float64
# z_16     float64
# y          int64
# ...

# %%
df.describe()
# Out:
#                x_0          y_0  ...         z_16            y
# count  1188.000000  1188.000000  ...  1188.000000  1188.000000
# mean      0.738152     0.742438  ...    -0.042786     0.614478
# std       0.137847     0.192470  ...     0.074833     0.486923
# min       0.270096     0.062608  ...    -0.214254     0.000000
# 25%       0.693043     0.699845  ...    -0.096471     0.000000
# 50%       0.792090     0.791810  ...    -0.047125     1.000000
# 75%       0.822707     0.846295  ...     0.010018     1.000000
# max       0.866762     0.961189  ...     0.269643     1.000000
#
# [8 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3',
#        'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5', 'x_6', 'y_6',
#        'z_6', 'x_7', 'y_7', 'z_7', 'x_8', 'y_8', 'z_8', 'x_9', 'y_9', 'z_9',
#        'x_10', 'y_10', 'z_10', 'x_11', 'y_11', 'z_11', 'x_12', 'y_12', 'z_12',
#        'x_13', 'y_13', 'z_13', 'x_14', 'y_14', 'z_14', 'x_15', 'y_15', 'z_15',
#        'x_16', 'y_16', 'z_16', 'y', 'image'],
#       dtype='object')

# %%
df = df.drop(['z_0', 'z_1', 'z_2', 'z_3', 'z_4', 'z_5', 'z_6', 'z_7', 'z_8', 'z_9', 'z_10', 'z_11', 'z_12', 'z_13', 'z_14', 'z_15', 'z_16'], axis=1)
df

# z 값 빼버리기
# Out:
#            x_0       y_0  ...  y                             image
# 0     0.813085  0.846067  ...  0  not_correct10.MP4_000002.243.jpg
# 1     0.811608  0.900154  ...  0  not_correct10.MP4_000004.040.jpg
# 2     0.804972  0.898247  ...  0  not_correct10.MP4_000004.240.jpg
# 3     0.810611  0.890062  ...  0  not_correct10.MP4_000004.440.jpg
# 4     0.813915  0.895303  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183  0.845585  0.939924  ...  1       correct4.mp4_000005.383.jpg
# 1184  0.846682  0.942074  ...  1       correct4.mp4_000005.450.jpg
# 1185  0.843230  0.931821  ...  1       correct4.mp4_000005.517.jpg
# 1186  0.846199  0.936584  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.844087  0.922825  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 36 columns]

# %% [markdown]
# # 점 관점 벡터화
# 모든 랜드마크를 0 번 랜드마크에서 빼는 것이라
# 원점을 0번 랜드마크로 두고 평행이동해주는 것
#
# # 벡터 관점 벡터화
# 모든 랜드마크를 i 번 - i-1번 해서
# 손 구조를 고려하여 벡터화 시키는 것.
# 이렇게 하면 모든 점의 시작이 원점으로 옮겨지는 것.
#
#
# 1. 벡터화 시키면 어느 포인트를 기준으로 모든 점들을 이쁘게 옮기는 것은 해결

# %%
df_vector = df.copy()

# %%
df_vector
# Out:
#            x_0       y_0  ...  y                             image
# 0     0.813085  0.846067  ...  0  not_correct10.MP4_000002.243.jpg
# 1     0.811608  0.900154  ...  0  not_correct10.MP4_000004.040.jpg
# 2     0.804972  0.898247  ...  0  not_correct10.MP4_000004.240.jpg
# 3     0.810611  0.890062  ...  0  not_correct10.MP4_000004.440.jpg
# 4     0.813915  0.895303  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183  0.845585  0.939924  ...  1       correct4.mp4_000005.383.jpg
# 1184  0.846682  0.942074  ...  1       correct4.mp4_000005.450.jpg
# 1185  0.843230  0.931821  ...  1       correct4.mp4_000005.517.jpg
# 1186  0.846199  0.936584  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.844087  0.922825  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 36 columns]

# %%
column = []
for i in range (0, 16):
  column.append('x_{1}-{0}'.format(i,i+1))
  column.append('y_{1}-{0}'.format(i,i+1))

column.append('y')
column.append('image')

# df_vector 의 columns 만들어주기

# %%
print(column)
# Out:
# ['x_1-0', 'y_1-0', 'x_2-1', 'y_2-1', 'x_3-2', 'y_3-2', 'x_4-3', 'y_4-3', 'x_5-4', 'y_5-4', 'x_6-5', 'y_6-5', 'x_7-6', 'y_7-6', 'x_8-7', 'y_8-7', 'x_9-8', 'y_9-8', 'x_10-9', 'y_10-9', 'x_11-10', 'y_11-10', 'x_12-11', 'y_12-11', 'x_13-12', 'y_13-12', 'x_14-13', 'y_14-13', 'x_15-14', 'y_15-14', 'x_16-15', 'y_16-15', 'y', 'image']

# %% [markdown]
# column 이 list 고, 이 list 를 묶어 놓은게 array

# %%
for i in range(0,16):
  df_vector['x_{0}'.format(i)] = df['x_{0}'.format(i+1)]-df['x_{0}'.format(i)]
  print('{0}번째 x 작업'.format(i))
  df_vector['y_{0}'.format(i)] = df['y_{0}'.format(i+1)]-df['y_{0}'.format(i)]
  print('{0}번째 y 작업'.format(i))
  # print(i+1), print(i)

  # 벡터화 해주는 코드
# Out:
# 0번째 x 작업
# 0번째 y 작업
# 1번째 x 작업
# 1번째 y 작업
# 2번째 x 작업
# 2번째 y 작업
# 3번째 x 작업
# 3번째 y 작업
# 4번째 x 작업
# 4번째 y 작업
# 5번째 x 작업
# 5번째 y 작업
# 6번째 x 작업
# 6번째 y 작업
# 7번째 x 작업
# 7번째 y 작업
# 8번째 x 작업
# 8번째 y 작업
# 9번째 x 작업
# 9번째 y 작업
# 10번째 x 작업
# 10번째 y 작업
# 11번째 x 작업
# 11번째 y 작업
# 12번째 x 작업
# 12번째 y 작업
# 13번째 x 작업
# 13번째 y 작업
# 14번째 x 작업
# 14번째 y 작업
# 15번째 x 작업
# 15번째 y 작업

# %%
df_vector
# Out:
#            x_0       y_0  ...  y                             image
# 0     0.011337 -0.075457  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.011376 -0.096157  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.009913 -0.079739  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.012914 -0.078981  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.014134 -0.105717  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.011339 -0.172951  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.005188 -0.175360  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.004403 -0.176916  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.002079 -0.170642  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.000348 -0.163031  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 36 columns]

# %%
df
# Out:
#            x_0       y_0  ...  y                             image
# 0     0.813085  0.846067  ...  0  not_correct10.MP4_000002.243.jpg
# 1     0.811608  0.900154  ...  0  not_correct10.MP4_000004.040.jpg
# 2     0.804972  0.898247  ...  0  not_correct10.MP4_000004.240.jpg
# 3     0.810611  0.890062  ...  0  not_correct10.MP4_000004.440.jpg
# 4     0.813915  0.895303  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183  0.845585  0.939924  ...  1       correct4.mp4_000005.383.jpg
# 1184  0.846682  0.942074  ...  1       correct4.mp4_000005.450.jpg
# 1185  0.843230  0.931821  ...  1       correct4.mp4_000005.517.jpg
# 1186  0.846199  0.936584  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.844087  0.922825  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 36 columns]

# %%
df_vector = df_vector.drop(['x_16', 'y_16'], axis=1)

# %%
df_vector
# Out:
#            x_0       y_0  ...  y                             image
# 0     0.011337 -0.075457  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.011376 -0.096157  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.009913 -0.079739  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.012914 -0.078981  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.014134 -0.105717  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.011339 -0.172951  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.005188 -0.175360  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.004403 -0.176916  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.002079 -0.170642  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.000348 -0.163031  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %%
df_vector.columns = column

# %%
df_vector

# 완성된 벡터 데이터
# Out:
#          x_1-0     y_1-0  ...  y                             image
# 0     0.011337 -0.075457  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.011376 -0.096157  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.009913 -0.079739  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.012914 -0.078981  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.014134 -0.105717  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.011339 -0.172951  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.005188 -0.175360  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.004403 -0.176916  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.002079 -0.170642  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.000348 -0.163031  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %% [markdown]
# 여기까지 첫번째 정규화, 즉 모든 벡터를 어느 기준점으로 옮기는 작업 완료!!!
#
# # 이제부터 크기 정규화 해야함.
#
# 그러기 위해서는 벡터를 벡터의 크기 데이터로 뽑아내야한다.
#
#
#
#
# 2. 크기 정규화는
# 기존의 벡터의 크기에서 min 값과 max 값의 차이가가장 작은 것을 기준으로 할지,\
# 혹은 min 값이나 max 값이 가장 작은 것으로 할지,\
# 혹은 예전에 이야기 했던 2,3번 랜드마크로 할지
#
# 다 해봐야한다

# %%
df_vector.describe()
# Out:
#              x_1-0        y_1-0  ...      y_16-15            y
# count  1188.000000  1188.000000  ...  1188.000000  1188.000000
# mean     -0.012693    -0.088487  ...     0.039778     0.614478
# std       0.034513     0.086511  ...     0.030504     0.486923
# min      -0.131951    -0.220007  ...    -0.064467     0.000000
# 25%      -0.031284    -0.152040  ...     0.028723     0.000000
# 50%      -0.011692    -0.096005  ...     0.048504     1.000000
# 75%       0.011093    -0.057200  ...     0.060111     1.000000
# max       0.054749     0.185444  ...     0.088450     1.000000
#
# [8 rows x 33 columns]

# %%
df_size = df_vector.copy()

# %%
column_size =[]

for i in range(0,16):
  column_size.append('size_{1}-{0}'.format(i,i+1))

# %%
column_size
# Out:
# ['size_1-0',
#  'size_2-1',
#  'size_3-2',
#  'size_4-3',
#  'size_5-4',
#  'size_6-5',
#  'size_7-6',
#  'size_8-7',
#  'size_9-8',
#  'size_10-9',
#  'size_11-10',
#  'size_12-11',
#  'size_13-12',
#  'size_14-13',
#  'size_15-14',
#  'size_16-15']

# %%
for i in range(0,16):
  df_size['x_{0}-{1}'.format(i+1,i)] = (df_vector['x_{0}-{1}'.format(i+1,i)]**2+df_vector['y_{0}-{1}'.format(i+1,i)]**2)**0.5
  print('{0}번째 x 작업'.format(i+1))
  # print(i+1), print(i)

  # 벡터의 크기 데이터를 만드는 코드
# Out:
# 1번째 x 작업
# 2번째 x 작업
# 3번째 x 작업
# 4번째 x 작업
# 5번째 x 작업
# 6번째 x 작업
# 7번째 x 작업
# 8번째 x 작업
# 9번째 x 작업
# 10번째 x 작업
# 11번째 x 작업
# 12번째 x 작업
# 13번째 x 작업
# 14번째 x 작업
# 15번째 x 작업
# 16번째 x 작업

# %%
df_size
# Out:
#          x_1-0     y_1-0  ...  y                             image
# 0     0.076304 -0.075457  ...  0  not_correct10.MP4_000002.243.jpg
# 1     0.096828 -0.096157  ...  0  not_correct10.MP4_000004.040.jpg
# 2     0.080353 -0.079739  ...  0  not_correct10.MP4_000004.240.jpg
# 3     0.080030 -0.078981  ...  0  not_correct10.MP4_000004.440.jpg
# 4     0.106658 -0.105717  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183  0.173322 -0.172951  ...  1       correct4.mp4_000005.383.jpg
# 1184  0.175436 -0.175360  ...  1       correct4.mp4_000005.450.jpg
# 1185  0.176970 -0.176916  ...  1       correct4.mp4_000005.517.jpg
# 1186  0.170655 -0.170642  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.163032 -0.163031  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %%
for i in range(0,16):
  df_size = df_size.drop('y_{0}-{1}'.format(i+1,i), axis=1)


df_size = df_size.drop(['y', 'image'], axis=1)
# 기존의 데이터에서 크기와 관련이 없어 필요 없는 데이터 삭제

# %%
df_size.columns = column_size
df_size

# 벡터의 크기 데이터 완성
# Out:
#       size_1-0  size_2-1  size_3-2  ...  size_14-13  size_15-14  size_16-15
# 0     0.076304  0.123414  0.108911  ...    0.070142    0.088503    0.062141
# 1     0.096828  0.115905  0.106251  ...    0.075909    0.094946    0.057582
# 2     0.080353  0.113302  0.106390  ...    0.072096    0.092160    0.060946
# 3     0.080030  0.110733  0.115656  ...    0.085199    0.098548    0.064604
# 4     0.106658  0.119401  0.106542  ...    0.076501    0.083172    0.061741
# ...        ...       ...       ...  ...         ...         ...         ...
# 1183  0.173322  0.179756  0.152823  ...    0.118291    0.098510    0.091869
# 1184  0.175436  0.177219  0.146912  ...    0.118368    0.095133    0.090820
# 1185  0.176970  0.170516  0.142344  ...    0.117454    0.087604    0.091387
# 1186  0.170655  0.173773  0.148878  ...    0.117332    0.092964    0.096019
# 1187  0.163032  0.171330  0.149304  ...    0.111077    0.099559    0.096557
#
# [1188 rows x 16 columns]

# %%
df_size.describe()
# Out:
#           size_1-0     size_2-1  ...   size_15-14   size_16-15
# count  1188.000000  1188.000000  ...  1188.000000  1188.000000
# mean      0.119701     0.137448  ...     0.063789     0.053739
# std       0.048296     0.032262  ...     0.023866     0.016408
# min       0.007939     0.024904  ...     0.003903     0.003523
# 25%       0.081533     0.112018  ...     0.043290     0.041868
# 50%       0.109935     0.131512  ...     0.065132     0.053590
# 75%       0.160484     0.161150  ...     0.081054     0.064605
# max       0.221002     0.221509  ...     0.116056     0.096857
#
# [8 rows x 16 columns]

# %%
# 벡터 크기의 min 값과 max 의 차이가 가장 작은 벡터를 찾는 코드

minmax = []
for i in range(0,16):
  minmax.append(max(df_size['size_{1}-{0}'.format(i, i+1)])-min(df_size['size_{1}-{0}'.format(i, i+1)]))

print(min(minmax))
print(minmax)
minmax.index(min(minmax))
# Out:
# 0.09333364113888912
# [0.21306318781374933, 0.19660495316917567, 0.14626174426609412, 0.13958564051347916, 0.19400938135803575, 0.13988719694511542, 0.1210187670420807, 0.10512466062341319, 0.2807606859986519, 0.12457761372796108, 0.13885953539913826, 0.10422443454261374, 0.25655647752424243, 0.11667232653761227, 0.11215263117910058, 0.09333364113888912]
# 15

# %% [markdown]
# 15로 나왔으니 결국 16-15 데이터를 쓰면 된다.
#
# 모든 벡터 다 통틀어서 벡터의 max값과 min 값의 차이가 가장 작은것, 즉, 데이터간 이 벡터만큼은 크게 변화가 없는 것. 그것이 16-15 벡터가 될 수 있다는 말.
#
# 그래서 16-15 벡터의 크기를 1로 단위화 시키고 그만큼 다른 벡터들의 크기를 보정해서 벡터에 반영해야함.

# %%
df_normed_16_15 = df_vector.copy()

# %%
df_normed_16_15
# Out:
#          x_1-0     y_1-0  ...  y                             image
# 0     0.011337 -0.075457  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.011376 -0.096157  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.009913 -0.079739  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.012914 -0.078981  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.014134 -0.105717  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.011339 -0.172951  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.005188 -0.175360  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.004403 -0.176916  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.002079 -0.170642  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.000348 -0.163031  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %%
dtype((df_normed_16_15['x_16-15']**2+df_normed_16_15['y_16-15']**2)**0.5)
# Out:
# dtype('float64')

# %%
array((df_normed_16_15['x_16-15']**2+df_normed_16_15['y_16-15']**2)**0.5)[0]
# Out:
# 0.06214113310362717

# %%
df_normed_16_15.iloc[0, :32]
# Out:
# x_1-0       0.0113367
# y_1-0      -0.0754569
# x_2-1      -0.0271393
# y_2-1       -0.120393
# x_3-2      -0.0548431
# y_3-2       -0.094095
# x_4-3      -0.0510712
# y_4-3      -0.0891749
# x_5-4        0.125701
# y_5-4      0.00460061
# x_6-5      -0.0781911
# y_6-5      -0.0595826
# x_7-6      -0.0567108
# y_7-6      0.00902259
# x_8-7      -0.0422004
# y_8-7       0.0253638
# x_9-8        0.143136
# y_9-8       0.0631967
# x_10-9     -0.0795956
# y_10-9     -0.0393524
# x_11-10    -0.0404447
# y_11-10     0.0640817
# x_12-11    -0.0278785
# y_12-11     0.0564169
# x_13-12       0.11806
# y_13-12    -0.0379131
# x_14-13    -0.0692778
# y_14-13     0.0109749
# x_15-14    -0.0179691
# y_15-14     0.0866601
# x_16-15   -0.00791347
# y_16-15     0.0616352
# Name: 0, dtype: object

# %%
df_vector.iloc[1187, :32]/array((df_vector['x_16-15']**2+df_vector['y_16-15']**2)**0.5)[1187]

# 원하는 값 도출되는것 확인
# Out:
# x_1-0      0.00360503
# y_1-0        -1.68845
# x_2-1       -0.505763
# y_2-1        -1.70079
# x_3-2       -0.872193
# y_3-2        -1.27681
# x_4-3        -0.64388
# y_4-3        -1.36397
# x_5-4         1.59748
# y_5-4        0.173002
# x_6-5       -0.879902
# y_6-5        -1.13019
# x_7-6       -0.726969
# y_7-6        0.472646
# x_8-7       -0.442574
# y_8-7          1.0393
# x_9-8         1.46458
# y_9-8        0.285259
# x_10-9      -0.958003
# y_10-9       -1.20262
# x_11-10     -0.780239
# y_11-10      0.661975
# x_12-11     -0.468354
# y_12-11      0.955628
# x_13-12       1.73145
# y_13-12      0.418899
# x_14-13     -0.917569
# y_14-13     -0.693851
# x_15-14     -0.708387
# y_15-14      0.749224
# x_16-15      -0.42798
# y_16-15      0.903788
# Name: 1187, dtype: object

# %%
for i in range(0,1188):
  df_normed_16_15.iloc[i, :32] = df_vector.iloc[i, :32]/array((df_vector['x_16-15']**2+df_vector['y_16-15']**2)**0.5)[i]

# 모든 값들을 기준에 맞게 normalize 해줌.

# %%
df_normed_16_15
# Out:
#          x_1-0     y_1-0  ...  y                             image
# 0     0.182435 -1.214283  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.197568 -1.669925  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.162654 -1.308366  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.199891 -1.222536  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.228928 -1.712267  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.123427 -1.882587  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.057121 -1.930839  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.048179 -1.935884  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.021648 -1.777165  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.003605 -1.688448  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %%
(-0.127347)**2+0.991858**2
# Out:
# 0.999999550573

# %%
df_save1 = pd.DataFrame(df_normed_16_15)
# df_save1.to_excel(excel_writer='C:\\Users\\sjhh4\\python\\데이터 청년 캠퍼스\\프로젝트\\학습 데이터\\뉴데이터 landmark 좌표값\\newdata_all_0818_normed_16_15.xlsx', index=None, header=True)

# %%
with pd.ExcelWriter('newdata_all_0818_normed_16_15.xlsx') as writer: 

  df_save1.to_excel(writer, sheet_name='data',index=None, header=True)

files.download('newdata_all_0818_normed_16_15.xlsx')

# %%
df_save1
# Out:
#          x_1-0     y_1-0  ...  y                             image
# 0     0.182435 -1.214283  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.197568 -1.669925  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.162654 -1.308366  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.199891 -1.222536  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.228928 -1.712267  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.123427 -1.882587  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.057121 -1.930839  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.048179 -1.935884  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.021648 -1.777165  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.003605 -1.688448  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %% [markdown]
# # 가장 작은 벡터의 크기를 1로 만드는 크기 정규화

# %%
df_size.describe()
# Out:
#           size_1-0     size_2-1  ...   size_15-14   size_16-15
# count  1188.000000  1188.000000  ...  1188.000000  1188.000000
# mean      0.119701     0.137448  ...     0.063789     0.053739
# std       0.048296     0.032262  ...     0.023866     0.016408
# min       0.007939     0.024904  ...     0.003903     0.003523
# 25%       0.081533     0.112018  ...     0.043290     0.041868
# 50%       0.109935     0.131512  ...     0.065132     0.053590
# 75%       0.160484     0.161150  ...     0.081054     0.064605
# max       0.221002     0.221509  ...     0.116056     0.096857
#
# [8 rows x 16 columns]

# %%
df_normed_min = df_vector.copy()

# %%
for i in range(0, 16):
  print(min(df_size['size_{1}-{0}'.format(i, i+1)]))
# Out:
# 0.007938898172504653
# 0.024904012333256304
# 0.034683861717689286
# 0.021624930565748365
# 0.04901765228338054
# 0.030167981888707722
# 0.005219543031205862
# 0.005097210872847504
# 0.019363840106590972
# 0.03865634129508278
# 0.003328134597164434
# 0.0025604479861893767
# 0.02909917945323136
# 0.027905103622444787
# 0.003902913589956437
# 0.003522932077158034

# %%
mins = []
for i in range(0,16):
  mins.append(min(df_size['size_{1}-{0}'.format(i, i+1)]))

print(min(mins))
print(mins)
mins.index(min(mins))
# Out:
# 0.0025604479861893767
# [0.007938898172504653, 0.024904012333256304, 0.034683861717689286, 0.021624930565748365, 0.04901765228338054, 0.030167981888707722, 0.005219543031205862, 0.005097210872847504, 0.019363840106590972, 0.03865634129508278, 0.003328134597164434, 0.0025604479861893767, 0.02909917945323136, 0.027905103622444787, 0.003902913589956437, 0.003522932077158034]
# 11

# %%
df_normed_min
# Out:
#          x_1-0     y_1-0  ...  y                             image
# 0     0.011337 -0.075457  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.011376 -0.096157  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.009913 -0.079739  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.012914 -0.078981  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.014134 -0.105717  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.011339 -0.172951  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.005188 -0.175360  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.004403 -0.176916  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.002079 -0.170642  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.000348 -0.163031  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %%
df_normed_min = pd.DataFrame(df_normed_min)

# %%
df_normed_min
# Out:
#          x_1-0     y_1-0  ...  y                             image
# 0     0.011337 -0.075457  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -0.011376 -0.096157  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -0.009913 -0.079739  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -0.012914 -0.078981  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -0.014134 -0.105717  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...       ...  ... ..                               ...
# 1183 -0.011339 -0.172951  ...  1       correct4.mp4_000005.383.jpg
# 1184 -0.005188 -0.175360  ...  1       correct4.mp4_000005.450.jpg
# 1185 -0.004403 -0.176916  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.002079 -0.170642  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.000348 -0.163031  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %%
df_normed_min.iloc[:, :32]
# Out:
#          x_1-0     y_1-0     x_2-1  ...   y_15-14   x_16-15   y_16-15
# 0     0.011337 -0.075457 -0.027139  ...  0.086660 -0.007913  0.061635
# 1    -0.011376 -0.096157 -0.030411  ...  0.092131 -0.004325  0.057419
# 2    -0.009913 -0.079739 -0.028393  ...  0.088900 -0.010591  0.060018
# 3    -0.012914 -0.078981 -0.031546  ...  0.092001 -0.018800  0.061808
# 4    -0.014134 -0.105717 -0.033857  ...  0.079653 -0.014164  0.060094
# ...        ...       ...       ...  ...       ...       ...       ...
# 1183 -0.011339 -0.172951 -0.050850  ...  0.065841 -0.044392  0.080432
# 1184 -0.005188 -0.175360 -0.051540  ...  0.057289 -0.050837  0.075260
# 1185 -0.004403 -0.176916 -0.050062  ...  0.057927 -0.037712  0.083243
# 1186 -0.002079 -0.170642 -0.051533  ...  0.061675 -0.044486  0.085093
# 1187  0.000348 -0.163031 -0.048835  ...  0.072343 -0.041324  0.087267
#
# [1188 rows x 32 columns]

# %%
min(mins)
# Out:
# 0.0025604479861893767

# %%
for i in range(0,1188):
  df_normed_min.iloc[i, :32] = df_vector.iloc[i, :32]/min(mins)

# %%
df_normed_min
# Out:
#          x_1-0      y_1-0  ...  y                             image
# 0     4.427641 -29.470201  ...  0  not_correct10.MP4_000002.243.jpg
# 1    -4.443075 -37.554739  ...  0  not_correct10.MP4_000004.040.jpg
# 2    -3.871599 -31.142657  ...  0  not_correct10.MP4_000004.240.jpg
# 3    -5.043580 -30.846618  ...  0  not_correct10.MP4_000004.440.jpg
# 4    -5.520240 -41.288572  ...  0  not_correct10.MP4_000004.640.jpg
# ...        ...        ...  ... ..                               ...
# 1183 -4.428572 -67.547204  ...  1       correct4.mp4_000005.383.jpg
# 1184 -2.026110 -68.487908  ...  1       correct4.mp4_000005.450.jpg
# 1185 -1.719619 -69.095536  ...  1       correct4.mp4_000005.517.jpg
# 1186 -0.811808 -66.645515  ...  1       correct4.mp4_000005.583.jpg
# 1187  0.135949 -63.673021  ...  1       correct4.mp4_000005.650.jpg
#
# [1188 rows x 34 columns]

# %%
df_normed_min.describe()
# Out:
#              x_1-0        y_1-0  ...      y_16-15            y
# count  1188.000000  1188.000000  ...  1188.000000  1188.000000
# mean     -4.957177   -34.559177  ...    15.535652     0.614478
# std      13.479192    33.787259  ...    11.913570     0.486923
# min     -51.534308   -85.925339  ...   -25.178195     0.000000
# 25%     -12.218226   -59.380241  ...    11.217858     0.000000
# 50%      -4.566349   -37.495214  ...    18.943424     1.000000
# 75%       4.332622   -22.339846  ...    23.476827     1.000000
# max      21.382405    72.426201  ...    34.544590     1.000000
#
# [8 rows x 33 columns]

# %%
with pd.ExcelWriter('newdata_all_0818_normed_min.xlsx') as writer: 

  df_save1.to_excel(writer, sheet_name='data',index=False, header=True)

files.download('newdata_all_0818_normed_min.xlsx')

# %%
df_normed_min.describe()
# Out:
#              x_1-0        y_1-0  ...      y_16-15            y
# count  1188.000000  1188.000000  ...  1188.000000  1188.000000
# mean     -4.957177   -34.559177  ...    15.535652     0.614478
# std      13.479192    33.787259  ...    11.913570     0.486923
# min     -51.534308   -85.925339  ...   -25.178195     0.000000
# 25%     -12.218226   -59.380241  ...    11.217858     0.000000
# 50%      -4.566349   -37.495214  ...    18.943424     1.000000
# 75%       4.332622   -22.339846  ...    23.476827     1.000000
# max      21.382405    72.426201  ...    34.544590     1.000000
#
# [8 rows x 33 columns]
