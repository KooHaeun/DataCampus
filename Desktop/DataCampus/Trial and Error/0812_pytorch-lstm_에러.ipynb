# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path='/content/drive/Shareddrives/데이터 청년 캠퍼스/젓가락질 데이터/새 젓가락질 데이터/excel 파일/newdata1_notcorrect.xlsx'

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_excel(path)

# %%
data.head()
# Out:
#    Unnamed: 0       x_0       y_0  ...      z_16  y                            image
# 0           0  0.842716  0.782446  ...  0.096160  0  not_correct6.mp4_000000.865.jpg
# 1           1  0.833609  0.812045  ...  0.104297  0  not_correct6.mp4_000001.133.jpg
# 2           2  0.827795  0.811853  ...  0.097003  0  not_correct6.mp4_000001.067.jpg
# 3           3  0.822658  0.805489  ...  0.060277  0  not_correct6.mp4_000000.995.jpg
# 4           4  0.822961  0.789329  ...  0.047452  0  not_correct6.mp4_000000.931.jpg
#
# [5 rows x 54 columns]

# %%
data = data.set_index('image')

# %%
data.head()
# Out:
#                                  Unnamed: 0       x_0  ...      z_16  y
# image                                                  ...
# not_correct6.mp4_000000.865.jpg           0  0.842716  ...  0.096160  0
# not_correct6.mp4_000001.133.jpg           1  0.833609  ...  0.104297  0
# not_correct6.mp4_000001.067.jpg           2  0.827795  ...  0.097003  0
# not_correct6.mp4_000000.995.jpg           3  0.822658  ...  0.060277  0
# not_correct6.mp4_000000.931.jpg           4  0.822961  ...  0.047452  0
#
# [5 rows x 53 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  97 non-null     int64
#  1   x_0         97 non-null     float64
#  2   y_0         97 non-null     float64
#  3   z_0         97 non-null     float64
#  4   x_1         97 non-null     float64
#  5   y_1         97 non-null     float64
#  6   z_1         97 non-null     float64
#  7   x_2         97 non-null     float64
#  8   y_2         97 non-null     float64
#  9   z_2         97 non-null     float64
#  10  x_3         97 non-null     float64
#  11  y_3         97 non-null     float64
#  12  z_3         97 non-null     float64
#  13  x_4         97 non-null     float64
#  14  y_4         97 non-null     float64
#  15  z_4         97 non-null     float64
#  16  x_5         97 non-null     float64
#  17  y_5         97 non-null     float64
# ...

# %%
x_0 = data['x_0'].values.astype(float)
y_0 = data['y_0'].values.astype(float)
z_0 = data['z_0'].values.astype(float)
x_1 = data['x_1'].values.astype(float)
y_1 = data['y_1'].values.astype(float)
z_1 = data['z_1'].values.astype(float)
x_2 = data['x_2'].values.astype(float)
y_2 = data['y_2'].values.astype(float)
z_2 = data['z_2'].values.astype(float)
x_3 = data['x_3'].values.astype(float)
y_3 = data['y_3'].values.astype(float)
z_3 = data['z_3'].values.astype(float)
x_4 = data['x_4'].values.astype(float)
y_4 = data['y_4'].values.astype(float)
z_4 = data['z_4'].values.astype(float)
x_5 = data['x_5'].values.astype(float)
y_5 = data['y_5'].values.astype(float)
z_5 = data['z_5'].values.astype(float)
x_6 = data['x_6'].values.astype(float)
y_6 = data['y_6'].values.astype(float)
z_6 = data['z_6'].values.astype(float)
x_7 = data['x_7'].values.astype(float)
y_7 = data['y_7'].values.astype(float)
z_7 = data['z_7'].values.astype(float)
x_8 = data['x_8'].values.astype(float)
y_8 = data['y_8'].values.astype(float)
z_8 = data['z_8'].values.astype(float)
x_9 = data['x_9'].values.astype(float)
y_9 = data['y_9'].values.astype(float)
z_9 = data['z_9'].values.astype(float)
x_10 = data['x_10'].values.astype(float)
y_10 = data['y_10'].values.astype(float)
z_10 = data['z_10'].values.astype(float)
x_11 = data['x_11'].values.astype(float)
y_11 = data['y_11'].values.astype(float)
z_11 = data['z_11'].values.astype(float)
x_12 = data['x_12'].values.astype(float)
y_12 = data['y_12'].values.astype(float)
z_12 = data['z_12'].values.astype(float)
x_13 = data['x_13'].values.astype(float)
y_13 = data['y_13'].values.astype(float)
z_13 = data['z_13'].values.astype(float)
x_14 = data['x_14'].values.astype(float)
y_14 = data['y_14'].values.astype(float)
z_14 = data['z_14'].values.astype(float)
x_15 = data['x_15'].values.astype(float)
y_15 = data['y_15'].values.astype(float)
z_15 = data['z_15'].values.astype(float)
x_16 = data['x_16'].values.astype(float)
y_16 = data['y_16'].values.astype(float)
z_16 = data['z_16'].values.astype(float)

# %%
learning_rate = 0.0001
sequence_length = 24
epochs = 200

# %%
def make_batch(input_data, sl) :
  train_x = []
  train_y = []
  L = len(input_data)
  for i in range(L-sl) :
    train_seq = input_data[i : i+sl]
    train_label = input_data[i+sl : sl+1]
    train_x.append(train_seq)
    train_y.append(train_label)
  return train_x, train_y

# %%
print(train_y)
# Out:
# [array([[0.81960225]]), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shape=(0, 1), dtype=float64), array([], shap
# ...

# %%
class simple_lstm(nn.Module) :

  def __init__(self) :
    super().__init__()
    self.input_vector = 1
    self.sequence_length = 24
    self.output_vector = 100
    self.num_layers = 4

    self.lstm = nn.LSTM(input_size=self.input_vector, hidden_size=self.output_vector, num_layers=self.num_layers, batch_first=True)
    self.linear = nn.Sequential(
        nn.Linear(self.output_vector, 50),
        nn.Linear(50, 30),
        nn.Linear(30, 10),
        nn.Linear(10,1)
        )
        
    def forward(self, x):
        output, _ = self.lstm(x) #(hidden, cell) 데이터는 사용하지 않음
        return self.linear(output[:,-1,:])
    
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
train_x, train_y = make_batch(x_0.reshape(-1,1), sequence_length)
tensor_x = torch.Tensor(train_x)
tensor_y = torch.Tensor(train_y)

x_0 = simple_lstm()
x_0 = x_0.to(device)

optimizer = torch.optim.Adam(x_0.parameters(), lr=learning_rate)
criterion = nn.MSELoss()


for i in range(epochs):
    x_0.train()
    tensor_x = tensor_x.to(device)
    tensor_y = tensor_y.to(device)
    output = x_0(tensor_x)
    loss = criterion(output, tensor_y.view(-1,1))
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if i%100 == 0:
        print('Epoch {}, Loss {:.5f}'.format(i, loss.item()))

x_input = np.array(data.x_0[-24:])
x_input = x_input.reshape((1, 24, 1)) 
x_0_pred = []

for i in range(672):
    x_input = torch.Tensor(x_input)
    x_input = x_input.to(device)
    predict = x_0(x_input).cpu().detach().numpy()
    
    new_input = predict.reshape((1,1,1))
    x_input = np.concatenate((x_input[:,-23:].cpu(), new_input), axis = 1)
    x_0_pred.append(predict[0][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-886ae0599bd5> in <module>()
#       1 train_x, train_y = make_batch(x_0.reshape(-1,1), sequence_length)
#       2 tensor_x = torch.Tensor(train_x)
# ----> 3 tensor_y = torch.Tensor(train_y)
#       4
#       5 x_0 = simple_lstm()
#
# ValueError: expected sequence of length 1 at dim 1 (got 0)
